# %% [markdown]
# ## **Reading the Dataset**

# %%
# !unzip /content/dog_data.zip
# Out:
# Archive:  /content/dog_data_short.zip
#    creating: dog_data/5898/
#   inflating: dog_data/5898/5898_A_2zMUSqlxKlkAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5898/5898_A_2zMUSqlxKlkAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5898/5898_A_IdUASo3kSSUAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5898/5898_A_Km6WQabbG9cAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5898/5898_A_yFmGSo2bp-cAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5898/5898_A_YwS1QpL6r00AAAAAAAAAAAAAAQAAAQ.jpg
#    creating: dog_data/5899/
#   inflating: dog_data/5899/5899_A__iVyQa-Ul-kAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5899/5899_A_1cY0SJWiw2gAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5899/5899_A_8PPFSJLo4y0AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5899/5899_A_aYeATJcaX1MAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5899/5899_A_OQH-TZVbsjsAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5899/5899_A_rXoUTpGp2akAAAAAAAAAAAAAAQAAAQ.jpg
#    creating: dog_data/5901/
#   inflating: dog_data/5901/5901_A_7iu8TpXAj0QAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5901/5901_A_7iu8TpXAj0QAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5901/5901_A_fVZwT4oJteAAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5901/5901_A_mEEyRI2A9fMAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5901/5901_A_mEEyRI2A9fMAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5901/5901_A_nrfAQ5bLQPoAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5901/5901_A_Q8HDR58ZuAwAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5901/5901_A_ZhFOTLvWldQAAAAAAAAAAAAAAQAAAQ.jpg
#    creating: dog_data/5902/
#   inflating: dog_data/5902/5902_A_BHAZQqSI3N4AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5902/5902_A_GJH7T7H_iloAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5902/5902_A_mbdXS47FykQAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5902/5902_A_muDGRIJTyNcAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5902/5902_A_muDGRIJTyNcAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5902/5902_A_tiodTJuNpegAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5902/5902_A_tiodTJuNpegAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5902/5902_A_vKhxQLRWwhkAAAAAAAAAAAAAAQAAAQ.jpg
#    creating: dog_data/5903/
#   inflating: dog_data/5903/5903_A__xmgSopzWN8AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5903/5903_A__xmgSopzWN8AAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5903/5903_A_1YVzSbIROi8AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5903/5903_A_1YVzSbIROi8AAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5903/5903_A_LSiaQrNCrMkAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5903/5903_A_mwbHSqmRhcQAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5903/5903_A_mwbHSqmRhcQAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5903/5903_A_q3NGSb8R88wAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5903/5903_A_Z4zcS4aqMeIAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5903/5903_A_Z4zcS4aqMeIAAAAAAAAAAAAAAQAAAQ-0.jpg
#    creating: dog_data/5904/
#   inflating: dog_data/5904/5904_A_2iAoQIypnLoAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5904/5904_A_7_k1RLN9nvMAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5904/5904_A_bv-GT6sWBVEAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5904/5904_A_bv-GT6sWBVEAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5904/5904_A_Db7ZTbup1uwAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5904/5904_A_iPsbSr7C5DcAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5904/5904_A_iPsbSr7C5DcAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5904/5904_A_PrB1S52mSxAAAAAAAAAAAAAAAQAAAQ.jpg
#    creating: dog_data/5905/
#   inflating: dog_data/5905/5905_A__-5CSqwIXuQAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5905/5905_A_2bxUSqLc6wAAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5905/5905_A_2bxUSqLc6wAAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5905/5905_A_2fEAQ6wRV78AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5905/5905_A_2fEAQ6wRV78AAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5905/5905_A_cG_XSostq6UAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5905/5905_A_mVW5RI4asboAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5905/5905_A_tnp-TKnLdn4AAAAAAAAAAAAAAQAAAQ.jpg
#    creating: dog_data/5907/
#   inflating: dog_data/5907/5907_A_dNP4R4O9ASkAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5907/5907_A_FSyZQ40qPbEAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5907/5907_A_FSyZQ40qPbEAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5907/5907_A_h-8AQKUCJ6wAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5907/5907_A_h-8AQKUCJ6wAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5907/5907_A_SWT7TpEfSXoAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5907/5907_A_TKDrRJ6csBwAAAAAAAAAAAAAAQAAAQ.jpg
#    creating: dog_data/5908/
#   inflating: dog_data/5908/5908_A_4lT3QpjRRVEAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5908/5908_A_4lT3QpjRRVEAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5908/5908_A_7B2HSpMadEgAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5908/5908_A_7B2HSpMadEgAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5908/5908_A_bZBRQL1eeLIAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5908/5908_A_FhkKRo6fxbsAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5908/5908_A_SsADSplZuU0AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5908/5908_A_YRDWQrX8B_UAAAAAAAAAAAAAAQAAAQ.jpg
#    creating: dog_data/5909/
#   inflating: dog_data/5909/5909_A_9SxdQYnmGb8AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5909/5909_A_9SxdQYnmGb8AAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5909/5909_A_BbMtSbuC4rkAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5909/5909_A_DY8LQqsgHUkAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5909/5909_A_DY8LQqsgHUkAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5909/5909_A_KRefSIqxAhMAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5909/5909_A_KRefSIqxAhMAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5909/5909_A_MLC0SYv23fwAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5909/5909_A_MLC0SYv23fwAAAAAAAAAAAAAAQAAAQ-0.jpg
#    creating: dog_data/5910/
#   inflating: dog_data/5910/5910_A_0jiiRbW7afUAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5910/5910_A_3HV_SoaRBjcAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5910/5910_A_7uWzQaplAc4AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5910/5910_A_7uWzQaplAc4AAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5910/5910_A_I-uhS4pzzngAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5910/5910_A_I-uhS4pzzngAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5910/5910_A_osmfTY9zXYgAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5910/5910_A_osmfTY9zXYgAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5910/5910_A_qXnRSq_alQ0AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5910/5910_A_qXnRSq_alQ0AAAAAAAAAAAAAAQAAAQ-0.jpg
#    creating: dog_data/5911/
#   inflating: dog_data/5911/5911_A_eyX9SoPYLnUAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5911/5911_A_iGqzSrLtlcMAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5911/5911_A_kjIITIS-f1QAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5911/5911_A_kRgtTKT8j2YAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5911/5911_A_kRgtTKT8j2YAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5911/5911_A_qi_5T4aATlcAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5911/5911_A_UixUQJGzJ6AAAAAAAAAAAAAAAQAAAQ-0.jpg
#    creating: dog_data/5912/
#   inflating: dog_data/5912/5912_A_6r0MSZSuGksAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5912/5912_A_-BFZSoRxTq0AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5912/5912_A_MOhrQLLyVDYAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5912/5912_A_PD58S5qjNQoAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5912/5912_A_PD58S5qjNQoAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5912/5912_A_spOYSaQ52GMAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5912/5912_A_spOYSaQ52GMAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5912/5912_A_uUKRRIhcetkAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5912/5912_A_uUKRRIhcetkAAAAAAAAAAAAAAQAAAQ-0.jpg
#    creating: dog_data/5913/
#   inflating: dog_data/5913/5913_A_2QqWQqUlH60AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5913/5913_A_2QqWQqUlH60AAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5913/5913_A_AZo8QKwUkYAAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5913/5913_A_c_7LRYptgZ4AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5913/5913_A_FGfzSpRlJ9AAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5913/5913_A_FGfzSpRlJ9AAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5913/5913_A_gmv7RZlv2wwAAAAAAAAAAAAAAQAAAQ-0.jpg
#    creating: dog_data/5914/
#   inflating: dog_data/5914/5914_A_DycSQ4vvV68AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5914/5914_A_DycSQ4vvV68AAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5914/5914_A_e6vmTbdC-9oAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5914/5914_A_e6vmTbdC-9oAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5914/5914_A_En5pQIHy308AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5914/5914_A_OT8IQIP4z90AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5914/5914_A_OT8IQIP4z90AAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5914/5914_A_plhwSYSpPVIAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5914/5914_A_plhwSYSpPVIAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5914/5914_A_tdauTaw260cAAAAAAAAAAAAAAQAAAQ.jpg
#    creating: dog_data/5915/
#   inflating: dog_data/5915/5915_A_41GqSJs5RO4AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5915/5915_A_4ERZQIbzN0oAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5915/5915_A_dMj3SrywR0MAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5915/5915_A_dMj3SrywR0MAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5915/5915_A_K4WSQ7vM7ccAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5915/5915_A_NuL2TKMEwowAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5915/5915_A_P2osQYmaO-sAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5915/5915_A_P2osQYmaO-sAAAAAAAAAAAAAAQAAAQ-0.jpg
#    creating: dog_data/5916/
#   inflating: dog_data/5916/5916_A_88GIR4a9ssoAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5916/5916_A_BTUkT4Eo6pQAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5916/5916_A_higyRahZ3-cAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5916/5916_A_higyRahZ3-cAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5916/5916_A_HrtOQaj2IdIAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5916/5916_A_JywcTrmEceIAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5916/5916_A_pZKQQ6RiMPMAAAAAAAAAAAAAAQAAAQ.jpg
#    creating: dog_data/5917/
#   inflating: dog_data/5917/5917_A_2_HRRLUDXZsAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5917/5917_A_FEs-Ro6DnjoAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5917/5917_A_FEs-Ro6DnjoAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5917/5917_A_jHKHTLW4rOcAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5917/5917_A_KYy1R7vQUokAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5917/5917_A_ryBhQJmZFnUAAAAAAAAAAAAAAQAAAQ.jpg
#    creating: dog_data/5918/
#   inflating: dog_data/5918/5918_A__V74SLTYzbMAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5918/5918_A__V74SLTYzbMAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5918/5918_A_DEkJRYlXFNsAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5918/5918_A_gO6RRJre4hoAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5918/5918_A_gO6RRJre4hoAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5918/5918_A_HTT-TokpzUQAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5918/5918_A_HTT-TokpzUQAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5918/5918_A_WbF9SqahUZUAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5918/5918_A_WbF9SqahUZUAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5918/5918_A_ZX7pT4uWMgsAAAAAAAAAAAAAAQAAAQ-0.jpg
#    creating: dog_data/5919/
#   inflating: dog_data/5919/5919_A_5x75Rah9DIkAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5919/5919_A_5x75Rah9DIkAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5919/5919_A_JO5ZSKO_S7YAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5919/5919_A_JO5ZSKO_S7YAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5919/5919_A_KlKMQ7YwUQUAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5919/5919_A_KlKMQ7YwUQUAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5919/5919_A_P_orQb_1tnYAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5919/5919_A_Tq4LQ449vfgAAAAAAAAAAAAAAQAAAQ.jpg
#    creating: dog_data/5920/
#   inflating: dog_data/5920/5920_A_0RBhTJcWtikAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5920/5920_A_0RBhTJcWtikAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5920/5920_A_5GYYRZ6SqLkAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5920/5920_A_Bwx0RKWjg0sAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5920/5920_A_Bwx0RKWjg0sAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5920/5920_A_LTsOT5XBs1cAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5920/5920_A_QodUQrrQR2YAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5920/5920_A_RU49RpH8I6MAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5920/5920_A_RU49RpH8I6MAAAAAAAAAAAAAAQAAAQ-0.jpg
#    creating: dog_data/5921/
#   inflating: dog_data/5921/5921_A_437OSrredWUAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5921/5921_A_7RZWQ61W43wAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5921/5921_A_7RZWQ61W43wAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5921/5921_A_hZtcTJN4JNsAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5921/5921_A_I8uqQ7SlDm0AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5921/5921_A_I8uqQ7SlDm0AAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5921/5921_A_Ib-dTZ1rkF4AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5921/5921_A_nw_7QLxh6h4AAAAAAAAAAAAAAQAAAQ.jpg
#    creating: dog_data/5922/
#   inflating: dog_data/5922/5922_A_7t6EQYxDYbYAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5922/5922_A_7t6EQYxDYbYAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5922/5922_A_DNjCS6LPySIAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5922/5922_A_FeBCQrUGfIcAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5922/5922_A_FeBCQrUGfIcAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5922/5922_A_R094QKfEc7UAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5922/5922_A_y8iFSJzwNJ4AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5922/5922_A_zKqLQoDmJo0AAAAAAAAAAAAAAQAAAQ.jpg
#    creating: dog_data/5923/
#   inflating: dog_data/5923/5923_A__OfaT7yTwxUAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5923/5923_A_-fGnSJLpn7kAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5923/5923_A_sEMKS4Zum5UAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5923/5923_A_WPQkRZyeXvoAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5923/5923_A_WPQkRZyeXvoAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5923/5923_A_xgEcQJU0HaoAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5923/5923_A_Zg2QToXslCsAAAAAAAAAAAAAAQAAAQ.jpg
#    creating: dog_data/5924/
#   inflating: dog_data/5924/5924_A_Efp6QLrSZ-gAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5924/5924_A_Efp6QLrSZ-gAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5924/5924_A_gyLzR4cxZpIAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5924/5924_A_gyLzR4cxZpIAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5924/5924_A_MKWJQLqyZ8cAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5924/5924_A_MKWJQLqyZ8cAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5924/5924_A_u5XySKZ9cywAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5924/5924_A_WxikTrz0dTUAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5924/5924_A_WxikTrz0dTUAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5924/5924_A_xzWOSL6pNFAAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5924/5924_A_xzWOSL6pNFAAAAAAAAAAAAAAAQAAAQ-0.jpg
#    creating: dog_data/5925/
#   inflating: dog_data/5925/5925_A_3uJrSJQRo58AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5925/5925_A_3uJrSJQRo58AAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5925/5925_A_M9P2TpZaQRMAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5925/5925_A_M9P2TpZaQRMAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5925/5925_A_SPVDQZ3l49AAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5925/5925_A_UHH0So61ecgAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5925/5925_A_UHH0So61ecgAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5925/5925_A_YdltQ4U0sNcAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5925/5925_A_YdltQ4U0sNcAAAAAAAAAAAAAAQAAAQ-0.jpg
#    creating: dog_data/5926/
#   inflating: dog_data/5926/5926_A_eBxrT7u84_YAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5926/5926_A_jPNWSL4MPycAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5926/5926_A_jPNWSL4MPycAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5926/5926_A_mwleR627z8oAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5926/5926_A_mwleR627z8oAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5926/5926_A_Q2ygQ7cJQygAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5926/5926_A_q9E-TreZOpcAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5926/5926_A_q9E-TreZOpcAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5926/5926_A_yaQwRrApyMQAAAAAAAAAAAAAAQAAAQ.jpg
#    creating: dog_data/5927/
#   inflating: dog_data/5927/5927_A__5f3Qa27j5YAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5927/5927_A__5f3Qa27j5YAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5927/5927_A_ceTJQKFD4CcAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5927/5927_A_ceTJQKFD4CcAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5927/5927_A_cnG9T6Dm4UIAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5927/5927_A_Fe62T5TAJ7UAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5927/5927_A_Fe62T5TAJ7UAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5927/5927_A_UKkIRaJ9WRsAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5927/5927_A_UKkIRaJ9WRsAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5927/5927_A_zcYfTIvp2lMAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5927/5927_A_zcYfTIvp2lMAAAAAAAAAAAAAAQAAAQ-0.jpg
#    creating: dog_data/5928/
#   inflating: dog_data/5928/5928_A_1LQLSI-tEM4AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5928/5928_A_1LQLSI-tEM4AAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5928/5928_A_7MhsTIG0_08AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5928/5928_A_eaJbRIsiIAcAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5928/5928_A_eaJbRIsiIAcAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5928/5928_A_LFTBTrq2so4AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5928/5928_A_LFTBTrq2so4AAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5928/5928_A_Nt0WS7-bibUAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5928/5928_A_Nt0WS7-bibUAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5928/5928_A_PKCVSakmtxUAAAAAAAAAAAAAAQAAAQ.jpg
#    creating: dog_data/5929/
#   inflating: dog_data/5929/5929_A__dC3S5as98wAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5929/5929_A__dC3S5as98wAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5929/5929_A_BT-TSJ2u3kMAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5929/5929_A_BT-TSJ2u3kMAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5929/5929_A_dmmqQrIoeIMAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5929/5929_A_q1-cSYaye8AAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5929/5929_A_vgbBT4flQykAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5929/5929_A_wmoBRoo-T8IAAAAAAAAAAAAAAQAAAQ.jpg
#    creating: dog_data/5930/
#   inflating: dog_data/5930/5930_A_avXxR4A0gikAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5930/5930_A_CbtxSYI7W3wAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5930/5930_A_CbtxSYI7W3wAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5930/5930_A_CXUcR6GYNjkAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5930/5930_A_CXUcR6GYNjkAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5930/5930_A_lYW0R4XDx60AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5930/5930_A_lYW0R4XDx60AAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5930/5930_A_TQs9RbfFYCkAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5930/5930_A_YgagTY77Px8AAAAAAAAAAAAAAQAAAQ.jpg
#    creating: dog_data/5931/
#   inflating: dog_data/5931/5931_A_CaW2Rr7FxicAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5931/5931_A_CaW2Rr7FxicAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5931/5931_A_hD3uRIAU8WkAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5931/5931_A_iWCAS7hDyJEAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5931/5931_A_Pgp4TYloAOwAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5931/5931_A_Pgp4TYloAOwAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5931/5931_A_Yr4NS4nQky8AAAAAAAAAAAAAAQAAAQ.jpg
#    creating: dog_data/5932/
#   inflating: dog_data/5932/5932_7YkNrZhwSFKUwj4wGuhjBwAAACMAARAD.jpg
#   inflating: dog_data/5932/5932_dGG2aRuKRkqEOETt9YkP4gAAACMAARAD.jpg
#   inflating: dog_data/5932/5932_JikNLX13RouEBv1bQPnkMAAAACMAARAD.jpg
#   inflating: dog_data/5932/5932_rXxlFn69QMONIxtgsZJajQAAACMAARAD.jpg
#   inflating: dog_data/5932/5932_rXxlFn69QMONIxtgsZJajQAAACMAARAD-0.jpg
#   inflating: dog_data/5932/5932_T3Ow5yM2ThqSP6KFh8RfwAAAACMAARAD.jpg
#   inflating: dog_data/5932/5932_wlvKhmPsRnuzCvy0hg9dSQAAACMAARAD.jpg
#    creating: dog_data/5933/
#   inflating: dog_data/5933/5933_A_8SymQq9cMdAAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5933/5933_A_8SymQq9cMdAAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5933/5933_A_-cgBQ7nWdC4AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5933/5933_A_-cgBQ7nWdC4AAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5933/5933_A_rdK1TpMuf28AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5933/5933_A_ToioR6w5lKgAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5933/5933_A_UHv6TJv2h5cAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5933/5933_A_UvfzQoniuIkAAAAAAAAAAAAAAQAAAQ.jpg
#    creating: dog_data/5934/
#   inflating: dog_data/5934/5934_A_2YPaRq8ajt8AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5934/5934_A_6JGwQau_WNoAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5934/5934_A_6JGwQau_WNoAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5934/5934_A_MVBqSa4_cZAAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5934/5934_A_OQeoS4r3iwoAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5934/5934_A_OQeoS4r3iwoAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5934/5934_A_PIcHTa2SqFsAAAAAAAAAAAAAAQAAAQ.jpg
#    creating: dog_data/5935/
#   inflating: dog_data/5935/5935_A_5QphQrKDPQgAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5935/5935_A_5QphQrKDPQgAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5935/5935_A_8FKeQo04k4IAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5935/5935_A_8FKeQo04k4IAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5935/5935_A_ahcnSoV8REQAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5935/5935_A_jKAHQ6HeOiMAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5935/5935_A_lOYRTrARg8kAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5935/5935_A_N1bgTpTlLkIAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5935/5935_A_N1bgTpTlLkIAAAAAAAAAAAAAAQAAAQ-0.jpg
#    creating: dog_data/5936/
#   inflating: dog_data/5936/5936_A_63UvQ4t84sQAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5936/5936_A_KG1fRooRKKoAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5936/5936_A_MtxfT4wtikgAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5936/5936_A_MtxfT4wtikgAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5936/5936_A_opSGQJhnNSMAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5936/5936_A_opSGQJhnNSMAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5936/5936_A_USsBT7LiLzQAAAAAAAAAAAAAAQAAAQ.jpg
#    creating: dog_data/5937/
#   inflating: dog_data/5937/5937_A__LYISrzZ_GIAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5937/5937_A_8jMWRbavcW0AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5937/5937_A_8jMWRbavcW0AAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5937/5937_A_Ez49RbdLdmcAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5937/5937_A_ISDtSpuDW6MAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5937/5937_A_ISDtSpuDW6MAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5937/5937_A_VPDvSqwWeHQAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5937/5937_A_vTQoRLws130AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5937/5937_A_vTQoRLws130AAAAAAAAAAAAAAQAAAQ-0.jpg
#    creating: dog_data/5938/
#   inflating: dog_data/5938/5938_A_7zpaTrXCE1sAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5938/5938_A_7zpaTrXCE1sAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5938/5938_A_LgsSS74u2ZUAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5938/5938_A_LUknQ5zwlPEAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5938/5938_A_LUknQ5zwlPEAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5938/5938_A_qWCCR7R42PUAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5938/5938_A_qWCCR7R42PUAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5938/5938_A_ZKeCRqrD48cAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5938/5938_A_ZKeCRqrD48cAAAAAAAAAAAAAAQAAAQ-0.jpg
#    creating: dog_data/5939/
#   inflating: dog_data/5939/5939_A_bIcBTZ3tUqEAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5939/5939_A_FZxTQJDVbkYAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5939/5939_A_h0e0SItXSKwAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5939/5939_A_HlrvTLj4tU8AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5939/5939_A_meIyTZfLrbEAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5939/5939_A_P5EBT4AQhZcAAAAAAAAAAAAAAQAAAQ.jpg
#    creating: dog_data/5940/
#   inflating: dog_data/5940/5940_A_1P0yR4ETeMMAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5940/5940_A_3JWtT62FzhAAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5940/5940_A_6rXsToXOMygAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5940/5940_A_b2ToRI08f5UAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5940/5940_A_gZaiTKWdZY4AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5940/5940_A_gZaiTKWdZY4AAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5940/5940_A_ZT5FQpIeXlQAAAAAAAAAAAAAAQAAAQ.jpg
#    creating: dog_data/5941/
#   inflating: dog_data/5941/5941_f6GMYs9cRVe3Vy5EDVVBpgAAACMAARAD.jpg
#   inflating: dog_data/5941/5941_GkKIt_19Rh2gdu0uxH4mbgAAACMAARAD.jpg
#   inflating: dog_data/5941/5941_Gy5X3mM5RdSB0CqW4GSoGwAAACMAARAD.jpg
#   inflating: dog_data/5941/5941_Gy5X3mM5RdSB0CqW4GSoGwAAACMAARAD-0.jpg
#   inflating: dog_data/5941/5941_OjXGrQwIRLe0jn5ENTl1XwAAACMAARAD.jpg
#   inflating: dog_data/5941/5941_OjXGrQwIRLe0jn5ENTl1XwAAACMAARAD-0.jpg
#   inflating: dog_data/5941/5941_qyqNN_HDShqToEUCAcDKYQAAACMAARAD.jpg
#   inflating: dog_data/5941/5941_qyqNN_HDShqToEUCAcDKYQAAACMAARAD-0.jpg
#    creating: dog_data/5942/
#   inflating: dog_data/5942/5942_A_1OujSoSRAr8AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5942/5942_A_48nEQqmxm1UAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5942/5942_A_48nEQqmxm1UAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5942/5942_A_dQdlSJStdV8AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5942/5942_A_EBtBR7SR8xIAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5942/5942_A_SXh7Qo_BhxkAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5942/5942_A_VQ4tRoLu4e4AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5942/5942_A_VQ4tRoLu4e4AAAAAAAAAAAAAAQAAAQ-0.jpg
#    creating: dog_data/5943/
#   inflating: dog_data/5943/5943_A_FTXOTL2SfYwAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5943/5943_A_h0wES7JMcj8AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5943/5943_A_pNVfTIS6svkAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5943/5943_A_qAmbQo1B3boAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5943/5943_A_qAmbQo1B3boAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5943/5943_A_w7bqQ6XbEQoAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5943/5943_A_wxWxSZH1r_QAAAAAAAAAAAAAAQAAAQ.jpg
#    creating: dog_data/5944/
#   inflating: dog_data/5944/5944_A_4vgZSoQuhPgAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5944/5944_A_4vgZSoQuhPgAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5944/5944_A_6XZZT6vaEZ4AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5944/5944_A_6XZZT6vaEZ4AAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5944/5944_A_oEAqSaEmWGMAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5944/5944_A_PLH0TI0npUYAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5944/5944_A_PLH0TI0npUYAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5944/5944_A_ZBNoSpCehbIAAAAAAAAAAAAAAQAAAQ.jpg
#    creating: dog_data/5945/
#   inflating: dog_data/5945/5945_A_1XV-TI8AFDMAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5945/5945_A_1XV-TI8AFDMAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5945/5945_A_8vypTI74gzgAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5945/5945_A_8vypTI74gzgAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5945/5945_A_CAlCTIVL_TQAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5945/5945_A_CAlCTIVL_TQAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5945/5945_A_GSRPQoJj7dwAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5945/5945_A_Kgq_SLzseBQAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5945/5945_A_Pdg4R4YxRpwAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5945/5945_A_Pdg4R4YxRpwAAAAAAAAAAAAAAQAAAQ-0.jpg
#    creating: dog_data/5946/
#   inflating: dog_data/5946/5946_A_AK9lSaWJ_m0AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5946/5946_A_AK9lSaWJ_m0AAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5946/5946_A_a-RNSrOUV5IAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5946/5946_A_a-RNSrOUV5IAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5946/5946_A_I5KDRLmGgB8AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5946/5946_A_I5KDRLmGgB8AAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5946/5946_A_oVKNTpeuTjMAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5946/5946_A_oVKNTpeuTjMAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5946/5946_A_SRVGQbrSpNYAAAAAAAAAAAAAAQAAAQ.jpg
#    creating: dog_data/5947/
#   inflating: dog_data/5947/5947_A_02oeQZQGpSIAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5947/5947_A_02oeQZQGpSIAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5947/5947_A_1vE2T5QGHN4AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5947/5947_A_1vE2T5QGHN4AAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5947/5947_A_Hi3cQLCHj2wAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5947/5947_A_Hi3cQLCHj2wAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5947/5947_A_URuNQJscuisAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5947/5947_A_Y7LpQZ9WcMQAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5947/5947_A_zIdqT5wAadAAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5947/5947_A_zIdqT5wAadAAAAAAAAAAAAAAAQAAAQ-0.jpg
#    creating: dog_data/5948/
#   inflating: dog_data/5948/5948_A_5lrdQqJOweIAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5948/5948_A_82YISZVTz64AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5948/5948_A_jlGaToiTR1cAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5948/5948_A_JUa9QZwAOOgAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5948/5948_A_JUa9QZwAOOgAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5948/5948_A_OdypSY5DoYwAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5948/5948_A_qdWxRaREskIAAAAAAAAAAAAAAQAAAQ.jpg
#    creating: dog_data/5949/
#   inflating: dog_data/5949/5949_A_9Hj6Q4nQNhEAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5949/5949_A_9Hj6Q4nQNhEAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5949/5949_A_CkzZSIBF3KYAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5949/5949_A_CkzZSIBF3KYAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5949/5949_A_e69VSbQ41GQAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5949/5949_A_e69VSbQ41GQAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5949/5949_A_jyxVSZAdZnkAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5949/5949_A_kCm8SqJ4xbQAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5949/5949_A_ncTYTqtScNEAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5949/5949_A_ncTYTqtScNEAAAAAAAAAAAAAAQAAAQ-0.jpg
#    creating: dog_data/5950/
#   inflating: dog_data/5950/5950_A_1iq-SaD4TSYAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5950/5950_A_57b6Sb8-FAYAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5950/5950_A_He2nSrEFR1YAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5950/5950_A_n9rlSYbLOVMAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5950/5950_A_QMXJRr8rzh4AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5950/5950_A_QMXJRr8rzh4AAAAAAAAAAAAAAQAAAQ-0.jpg
#    creating: dog_data/5951/
#   inflating: dog_data/5951/5951_A_7HFFRY87DBIAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5951/5951_A_DAaRSIZ4OM0AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5951/5951_A_FliWQ7H5vocAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5951/5951_A_K0FxT6aY5N8AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5951/5951_A_uqQZTalXwHYAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5951/5951_A_WD_RToG7TiEAAAAAAAAAAAAAAQAAAQ.jpg
#    creating: dog_data/5952/
#   inflating: dog_data/5952/5952_A_5dNJRaepYnUAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5952/5952_A_7z2dSpjqRhsAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5952/5952_A_lq89RbvKMb8AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5952/5952_A_lq89RbvKMb8AAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5952/5952_A_TYT0T4Fvp38AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5952/5952_A_wSWmTr7_FucAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5952/5952_A_wSWmTr7_FucAAAAAAAAAAAAAAQAAAQ-0.jpg
#    creating: dog_data/5953/
#   inflating: dog_data/5953/5953_A_7t5MRrn6fyUAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5953/5953_A_7t5MRrn6fyUAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5953/5953_A_8RO8SZ_cRhQAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5953/5953_A_CHCqQrj2mVQAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5953/5953_A_FtPrQpzl3BAAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5953/5953_A_Qee6TYh_N0AAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5953/5953_A_zfSUS4jx5k4AAAAAAAAAAAAAAQAAAQ.jpg
#    creating: dog_data/5954/
#   inflating: dog_data/5954/5954_A_1BkkT5s3pZkAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5954/5954_A_1BkkT5s3pZkAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5954/5954_A_3vZpQYswJPEAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5954/5954_A_m6o3TaR9GfMAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5954/5954_A_m6o3TaR9GfMAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5954/5954_A_reG_T7bejwwAAAAAAAAAAAAAAQAAAQ.jpg
#    creating: dog_data/5955/
#   inflating: dog_data/5955/5955_A_2FZXTozgPmkAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5955/5955_A_2yTCT6348MsAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5955/5955_A_fJ6qQJnwL64AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5955/5955_A_HHmHS7TxQaEAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5955/5955_A_IgaXRJ1OsMYAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5955/5955_A_vbu_TpWL6WUAAAAAAAAAAAAAAQAAAQ.jpg
#    creating: dog_data/5956/
#   inflating: dog_data/5956/5956_igBDl6ziSdODf-fpbtEL1wAAACMAARAD.jpg
#   inflating: dog_data/5956/5956_igBDl6ziSdODf-fpbtEL1wAAACMAARAD-0.jpg
#   inflating: dog_data/5956/5956_IJnfoTCGRzy_PnKxNA20FAAAACMAARAD.jpg
#   inflating: dog_data/5956/5956_obyrOEluQJ2NMnX7G7GA0wAAACMAARAD.jpg
#   inflating: dog_data/5956/5956_sXCLxmKsRfaVAGlXbY1y3wAAACMAARAD.jpg
#   inflating: dog_data/5956/5956_U1EDgPaORkycuNu19c1crAAAACMAARAD.jpg
#   inflating: dog_data/5956/5956_U1EDgPaORkycuNu19c1crAAAACMAARAD-0.jpg
#   inflating: dog_data/5956/5956_yUud5fmzR3q6UJMUV6hLQwAAACMAARAD.jpg
#    creating: dog_data/5957/
#   inflating: dog_data/5957/5957_0GdWO5icQbKwpuwrEKLdgwAAACMAARAD.jpg
#   inflating: dog_data/5957/5957_8iDXzLM4RtOtrlot95uL0AAAACMAARAD.jpg
#   inflating: dog_data/5957/5957_AxQOGcN4RkCPWfcMhYgBuQAAACMAARAD.jpg
#   inflating: dog_data/5957/5957_bcn92ETmR3OJk3KR9IsmiQAAACMAARAD.jpg
#   inflating: dog_data/5957/5957_bcn92ETmR3OJk3KR9IsmiQAAACMAARAD-0.jpg
#   inflating: dog_data/5957/5957_J1CtsgliQ_Wz7dWKjUh9SwAAACMAARAD.jpg
#   inflating: dog_data/5957/5957_p_poUnC6T06GTFnucmRJSwAAACMAARAD.jpg
#    creating: dog_data/5958/
#   inflating: dog_data/5958/5958_A__iBTRLnSgRsAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5958/5958_A_gWrIQ4S447oAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5958/5958_A_hPGSRoU0C8kAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5958/5958_A_Sh8kTJUrbZoAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5958/5958_A_SsVBRJzukC8AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5958/5958_A_vBLvSIjsr5oAAAAAAAAAAAAAAQAAAQ.jpg
#    creating: dog_data/5959/
#   inflating: dog_data/5959/5959_A_BUqXSoHm6xYAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5959/5959_A_D_SeQ4c--GwAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5959/5959_A_lPwKS7HXTIUAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5959/5959_A_m_SBTJ0x4UgAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5959/5959_A_mo3GRaXrNTgAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5959/5959_A_p1FURL5LiRoAAAAAAAAAAAAAAQAAAQ.jpg
#    creating: dog_data/5960/
#   inflating: dog_data/5960/5960_1DUlr4dURtqhdRrCS69ZgAAAACMAARAD.jpg
#   inflating: dog_data/5960/5960_7ACCezYsSqiEz-zehRjeGAAAACMAARAD.jpg
#   inflating: dog_data/5960/5960_C7LFRq-yQ3al5ElDQWDhUAAAACMAARAD.jpg
#   inflating: dog_data/5960/5960_IsIe7tHGSEe9XWBTYTZTqwAAACMAARAD.jpg
#   inflating: dog_data/5960/5960_kD-WZuK9Rae4NoG1n7HHwAAAACMAARAD.jpg
#   inflating: dog_data/5960/5960_VjekR6ueSNOq94VvNYUcgAAAACMAARAD.jpg
#    creating: dog_data/5961/
#   inflating: dog_data/5961/5961_A_4gGXSpGmh1YAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5961/5961_A_4gGXSpGmh1YAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5961/5961_A_aA69SpvZhQQAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5961/5961_A_aEr8SogcnnIAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5961/5961_A_HXWXTZxti_gAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5961/5961_A_HXWXTZxti_gAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5961/5961_A_viZgTZtLdIkAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5961/5961_A_viZgTZtLdIkAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5961/5961_A_YfwbQJ4I5K8AAAAAAAAAAAAAAQAAAQ.jpg
#    creating: dog_data/5962/
#   inflating: dog_data/5962/5962_A_4cscRbyF-t8AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5962/5962_A_8P78SYHj8vsAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5962/5962_A_c1QXTK5OHUMAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5962/5962_A_cUEKTLA6SR4AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5962/5962_A_e7dMTaR9QaEAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5962/5962_A_iyCnSJYS2eQAAAAAAAAAAAAAAQAAAQ.jpg
#    creating: dog_data/5963/
#   inflating: dog_data/5963/5963_A_7dSiR56sjZkAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5963/5963_A_9Wo1SqHv_yIAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5963/5963_A_i-nLRI_4Z-QAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5963/5963_A_KkNnR5qXorcAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5963/5963_A_S7r7Srj5r_wAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5963/5963_A_xl9CQIhvmFsAAAAAAAAAAAAAAQAAAQ.jpg
#    creating: dog_data/5964/
#   inflating: dog_data/5964/5964_A__ZWPQJQKX10AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5964/5964_A__ZWPQJQKX10AAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5964/5964_A_cbghTYuoEzQAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5964/5964_A_EsHfTJi2lYUAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5964/5964_A_Jt0NQ7kxnNgAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5964/5964_A_Xt5tQpzDINoAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5964/5964_A_Xt5tQpzDINoAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5964/5964_A_ZPyVR5KHewAAAAAAAAAAAAAAAQAAAQ.jpg
#    creating: dog_data/5965/
#   inflating: dog_data/5965/5965_32oZCggVTXitEpu5VNf6FAAAACMAARAD.jpg
#   inflating: dog_data/5965/5965_32oZCggVTXitEpu5VNf6FAAAACMAARAD-0.jpg
#   inflating: dog_data/5965/5965_bSowLH_QSz-W1UMpKjz0owAAACMAARAD.jpg
#   inflating: dog_data/5965/5965_IvmXxLWaQd-LKBYjjNz-zwAAACMAARAD.jpg
#   inflating: dog_data/5965/5965_IvmXxLWaQd-LKBYjjNz-zwAAACMAARAD-0.jpg
#   inflating: dog_data/5965/5965_RZ0pi9gnRguCbwW_2IFLegAAACMAARAD.jpg
#   inflating: dog_data/5965/5965_Tt0AYk7ASkeS8q4TGaZ2FAAAACMAARAD.jpg
#   inflating: dog_data/5965/5965_Tt0AYk7ASkeS8q4TGaZ2FAAAACMAARAD-0.jpg
#   inflating: dog_data/5965/5965_Z1qDRVboSz625P_djDkBSwAAACMAARAD.jpg
#    creating: dog_data/5966/
#   inflating: dog_data/5966/5966_2d-0eWw0TDKv5kSoh012ogAAACMAARAD.jpg
#   inflating: dog_data/5966/5966_8qks6YhlRy-wDJtrkIZaIgAAACMAARAD.jpg
#   inflating: dog_data/5966/5966_HO658TQUQEWkFzwQclWO6QAAACMAARAD.jpg
#   inflating: dog_data/5966/5966_kVx_E1ohTniMFhLQU_YaagAAACMAARAD.jpg
#   inflating: dog_data/5966/5966_kVx_E1ohTniMFhLQU_YaagAAACMAARAD-0.jpg
#   inflating: dog_data/5966/5966_shv8oNWbQzuuIU83B0uJKAAAACMAARAD.jpg
#   inflating: dog_data/5966/5966_zQs0kBsAS2mS20h_2hp37AAAACMAARAD.jpg
#    creating: dog_data/5967/
#   inflating: dog_data/5967/5967_A_4gn2Q6opsTUAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5967/5967_A_4rjUSryl48IAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5967/5967_A_6aJ8Sa2FS-YAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5967/5967_A_KBNRRqQe8vsAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5967/5967_A_lU5xT7JfAoEAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5967/5967_A_lU5xT7JfAoEAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5967/5967_A_oLSJS49B_k4AAAAAAAAAAAAAAQAAAQ.jpg
#    creating: dog_data/5968/
#   inflating: dog_data/5968/5968_A_0d9RQp7aDvQAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5968/5968_A_0d9RQp7aDvQAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5968/5968_A_FYeLRIlqv1sAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5968/5968_A_KtVrTIFqvwEAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5968/5968_A_pUauTrONA4lSN5NPuoRqAAAAAQAAAQ.jpg
#   inflating: dog_data/5968/5968_A_pUauTrONA4lSN5NPuoRqAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5968/5968_A_QQBWQ5OgNqcAAAAAAAAAAAAAAQAAAQ.jpg
#    creating: dog_data/5969/
#   inflating: dog_data/5969/5969_A_3skiQIpmWr0AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5969/5969_A_3skiQIpmWr0AAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5969/5969_A_bLPoRob0He8AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5969/5969_A_GtpMTbLtVR4AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5969/5969_A_GtpMTbLtVR4AAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5969/5969_A_M4T5Q43L2qAAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5969/5969_A_M4T5Q43L2qAAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5969/5969_A_mSuHQqYkujMAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5969/5969_A_pMrhQLroe0IAAAAAAAAAAAAAAQAAAQ.jpg
#    creating: dog_data/5970/
#   inflating: dog_data/5970/5970_A_DcniRp1IRU0AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5970/5970_A_ePq8Ras0owIAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5970/5970_A_JDCBRYXWhPEAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5970/5970_A_JDCBRYXWhPEAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5970/5970_A_mHpGR5oYn_kAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5970/5970_A_TfOESrI_z3wAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5970/5970_A_XJPfQZIMlRoAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5970/5970_A_XJPfQZIMlRoAAAAAAAAAAAAAAQAAAQ-0.jpg
#    creating: dog_data/5971/
#   inflating: dog_data/5971/5971_6FeS5IF9S-6wW1rE2DkkNgAAACMAARAD.jpg
#   inflating: dog_data/5971/5971_K36qV-IBRmOVon1zVvZi5gAAACMAARAD.jpg
#   inflating: dog_data/5971/5971_PWdM972oTLS4wJJ319jekgAAACMAARED.jpg
#   inflating: dog_data/5971/5971_QdzTTlrGTCCQ1F9xM9w-rwAAACMAARED.jpg
#   inflating: dog_data/5971/5971_T9sfxIkpSdiBNdMd91kAeAAAACMAARAD.jpg
#    creating: dog_data/5972/
#   inflating: dog_data/5972/5972_A_8g2uSoogj9AAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5972/5972_A_8g2uSoogj9AAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5972/5972_A_b1QxQpUO7yYAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5972/5972_A_b1QxQpUO7yYAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5972/5972_A_CUlQSpIInD0AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5972/5972_A_CUlQSpIInD0AAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5972/5972_A_ffGlTZG85-QAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5972/5972_A_ffGlTZG85-QAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5972/5972_A_-MVkTKb4CY0AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5972/5972_A_VsLNT7sWz3wAAAAAAAAAAAAAAQAAAQ.jpg
#    creating: dog_data/5973/
#   inflating: dog_data/5973/5973_9OMvA3NtSGCRN6ymcLH-cAAAACMAARAD.jpg
#   inflating: dog_data/5973/5973_eub05Tg8Ri20vTxIGswtRwAAACMAARAD.jpg
#   inflating: dog_data/5973/5973_eub05Tg8Ri20vTxIGswtRwAAACMAARAD-0.jpg
#   inflating: dog_data/5973/5973_i_qZgpvUQ6CuKFZzKixaaQAAACMAARAD.jpg
#   inflating: dog_data/5973/5973_lk6TjulLSlK2EtPG2bOT1wAAACMAARAD.jpg
#   inflating: dog_data/5973/5973_M00cOfTlQD-7SbSDoVEZiwAAACMAARAD.jpg
#   inflating: dog_data/5973/5973_pJMeyxnvRPOCrS-s9zDN6AAAACMAARAD.jpg
#    creating: dog_data/5974/
#   inflating: dog_data/5974/5974_A_3bzNSLXJbYOwMn1EhM5NdAAAAQAAAQ.jpg
#   inflating: dog_data/5974/5974_A_GBRjRJz7PoIAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5974/5974_A_s_pGQJkJX7cAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5974/5974_A_t7pjSY5KeJwAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5974/5974_A_Y3QbRJDhWOYAAAAAAAAAAAAAAQAAAQ.jpg
#    creating: dog_data/5975/
#   inflating: dog_data/5975/5975_A_FWz-SLCNxIMAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5975/5975_A_FWz-SLCNxIMAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5975/5975_A_Rx6HR586O4sAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5975/5975_A_Rx6HR586O4sAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5975/5975_A_TLSkT501MYQAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5975/5975_A_Zo3FTaoKRGMAAAAAAAAAAAAAAQAAAQ.jpg
#    creating: dog_data/5976/
#   inflating: dog_data/5976/5976_A_82BHQ5VJpoQAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5976/5976_A_hdpuRLEj1id2OI1JoO1-QAAAAQAAAQ.jpg
#   inflating: dog_data/5976/5976_A_QzE_Q4Jhu9wAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5976/5976_A_vLt5Tr-DehsAAAAAAAAAAAAAAQAAAQ.jpg
#    creating: dog_data/5977/
#   inflating: dog_data/5977/5977_46wgkuZZT6eVVCnVPQgrpgAAACMAARAD.jpg
#   inflating: dog_data/5977/5977_elFmGazMSCiTA9cBKwcuMwAAACMAARAD.jpg
#   inflating: dog_data/5977/5977_i9DxLNTFRVa_ErPFgVJ3uAAAACMAARAD.jpg
#   inflating: dog_data/5977/5977_oAlUaNt0SoOd1pDlZebq6QAAACMAARAD.jpg
#   inflating: dog_data/5977/5977_w3FwASvhSDy_zI6aKPh33gAAACMAARAD.jpg
#   inflating: dog_data/5977/5977_w3FwASvhSDy_zI6aKPh33gAAACMAARAD-0.jpg
#    creating: dog_data/5978/
#   inflating: dog_data/5978/5978_A_6h2TSpG2xLAAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5978/5978_A_8TLTSrYPUTUAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5978/5978_A_DLk9QaFF3W0AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5978/5978_A_h3xWQb_tMC0AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5978/5978_A_h3xWQb_tMC0AAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5978/5978_A_iTDeS5OoNC4AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5978/5978_A_k02wRqflDJcAAAAAAAAAAAAAAQAAAQ.jpg
#    creating: dog_data/5979/
#   inflating: dog_data/5979/5979_A_24StS7TQoCsAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5979/5979_A_2oJSS7TmnnsAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5979/5979_A_2oJSS7TmnnsAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5979/5979_A_hV6oRqWGM8sAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5979/5979_A_hV6oRqWGM8sAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5979/5979_A_I4uaQKtPPhAAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5979/5979_A_WcuHSKIfpFcAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5979/5979_A_y6cGQZTV6wkAAAAAAAAAAAAAAQAAAQ.jpg
#    creating: dog_data/5980/
#   inflating: dog_data/5980/5980_A__EmvQZaIrk0AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5980/5980_A_3C7oQa_cOiMAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5980/5980_A_3C7oQa_cOiMAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5980/5980_A_6anUTaPKAZ0AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5980/5980_A_HRkFRZKRfK4AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5980/5980_A_HRkFRZKRfK4AAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5980/5980_A_m7-sRo3H-HgAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5980/5980_A_m7-sRo3H-HgAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5980/5980_A_ytKZR43YYx0AAAAAAAAAAAAAAQAAAQ.jpg
#    creating: dog_data/5981/
#   inflating: dog_data/5981/5981_A_3S3LTZgdkc9UCstAt954pwAAAQAAAQ.jpg
#   inflating: dog_data/5981/5981_A_3S3LTZgdkc9UCstAt954pwAAAQAAAQ-0.jpg
#   inflating: dog_data/5981/5981_A_B17tQL9G7GAAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5981/5981_A_hYZoTq_XxmAAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5981/5981_A_hYZoTq_XxmAAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5981/5981_A_M6uVTLJ2EukAAAAAAAAAAAAAAQAAAQ.jpg
#    creating: dog_data/5982/
#   inflating: dog_data/5982/5982_A__cl2QLO2llEAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5982/5982_A__cl2QLO2llEAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5982/5982_A_0xRaQ4mC4A0AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5982/5982_A_8qvqS61s-g4AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5982/5982_A_8qvqS61s-g4AAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5982/5982_A_BM-IS64L6owAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5982/5982_A_jReTTbRAdgMAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5982/5982_A_jReTTbRAdgMAAAAAAAAAAAAAAQAAAQ-0.jpg
#    creating: dog_data/5983/
#   inflating: dog_data/5983/5983_A_50hVQpJOh38AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5983/5983_A_50hVQpJOh38AAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5983/5983_A_723fTJwuqewAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5983/5983_A_723fTJwuqewAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5983/5983_A_lPjNSaZ7r9wAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5983/5983_A_MqoKS5Y6Hm8AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5983/5983_A_xTY-S4O2kyYAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5983/5983_A_xTY-S4O2kyYAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5983/5983_A_Ysu4QqIqPYkAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5983/5983_A_Ysu4QqIqPYkAAAAAAAAAAAAAAQAAAQ-0.jpg
#    creating: dog_data/5984/
#   inflating: dog_data/5984/5984_A_8yHrSI9wXtsAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5984/5984_A_8yHrSI9wXtsAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5984/5984_A_9z7ISKHMk40AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5984/5984_A_fpLuRr0nwKkAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5984/5984_A_K3lrQrI1-gIAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5984/5984_A_MPg-Tqt0h4UAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5984/5984_A_W2IxTrShf0MAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5984/5984_A_W2IxTrShf0MAAAAAAAAAAAAAAQAAAQ-0.jpg
#    creating: dog_data/5985/
#   inflating: dog_data/5985/5985_A_33L3RYDwFfYAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5985/5985_A_k02XTah-AqkAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5985/5985_A_PNRuRprSSG4AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5985/5985_A_PNRuRprSSG4AAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5985/5985_A_TFw1RY0S3r8AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5985/5985_A_uzHRSJ5nN_cAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5985/5985_A_WJZqQYuskC4AAAAAAAAAAAAAAQAAAQ.jpg
#    creating: dog_data/5986/
#   inflating: dog_data/5986/5986_A_acoIRKkS4KMAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5986/5986_A_C1q8QJNLNrEAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5986/5986_A_LngHSpFXTD4AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5986/5986_A_LngHSpFXTD4AAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5986/5986_A_M-KbRYPdAHoAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5986/5986_A_VW4rTbmlHh8AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5986/5986_A_ZlCjSaYPrmAAAAAAAAAAAAAAAQAAAQ.jpg
#    creating: dog_data/5987/
#   inflating: dog_data/5987/5987_A_aMsUT5Uw1pYAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5987/5987_A_b4GpSbjTmGoAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5987/5987_A_BUreSr9QuYgAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5987/5987_A_iAk4T7b-HD4AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5987/5987_A_olfhSYntr84AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5987/5987_A_XHurTYV1xScAAAAAAAAAAAAAAQAAAQ.jpg
#    creating: dog_data/5988/
#   inflating: dog_data/5988/5988_A_45ZeSYlRX04AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5988/5988_A_9f9RQYMEDW8AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5988/5988_A_9f9RQYMEDW8AAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5988/5988_A_C0HtTLNKeLkAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5988/5988_A_KhFwTKJ4XWwAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5988/5988_A_nxAwQ7FMivcAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5988/5988_A_nxAwQ7FMivcAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5988/5988_A_peVaRKhGG6EAAAAAAAAAAAAAAQAAAQ.jpg
#    creating: dog_data/5989/
#   inflating: dog_data/5989/5989_A_DOgCRJB2qgIAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5989/5989_A_fAd6Q6jPCKAAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5989/5989_A_fdXCTprSOxYAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5989/5989_A_Ij0mS4-M_jMAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5989/5989_A_TdNTTqxkNsEAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5989/5989_A_YkhcSryYe2cAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5989/5989_A_YkhcSryYe2cAAAAAAAAAAAAAAQAAAQ-0.jpg
#    creating: dog_data/5990/
#   inflating: dog_data/5990/5990_A__53oQqKI9vwAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5990/5990_A_ACH-Ta-cq-oAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5990/5990_A_ACH-Ta-cq-oAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5990/5990_A_gzSGTYTpSLkAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5990/5990_A_Tgc3Sb0KwMEAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5990/5990_A_V3ppS6VZwMoAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5990/5990_A_V3ppS6VZwMoAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5990/5990_A_vAl2Q52NU9MAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5990/5990_A_vAl2Q52NU9MAAAAAAAAAAAAAAQAAAQ-0.jpg
#    creating: dog_data/5991/
#   inflating: dog_data/5991/5991_A_Cl0sQ69mrY4AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5991/5991_A_CRqJQKCtnOMAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5991/5991_A_nZIFTqwyAG0AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5991/5991_A_OcaLQYiU_1EAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5991/5991_A_Vhx1SK59uV8AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5991/5991_A_zE7OR59AboMAAAAAAAAAAAAAAQAAAQ.jpg
#    creating: dog_data/5992/
#   inflating: dog_data/5992/5992_A_2M0vSKrxwocAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5992/5992_A_2M0vSKrxwocAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5992/5992_A_fhlXTKaMzqIAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5992/5992_A_GdTOQ6xnzZMAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5992/5992_A_LRDNQb_6khoAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5992/5992_A_LRDNQb_6khoAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5992/5992_A_NjG2SqOfUE4AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5992/5992_A_zd7bSJAblkwAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5992/5992_A_zd7bSJAblkwAAAAAAAAAAAAAAQAAAQ-0.jpg
#    creating: dog_data/5993/
#   inflating: dog_data/5993/5993_A_5pjuQ6bpF44AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5993/5993_A_5rhHQ4uH0DUAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5993/5993_A_b1eiQ4BovAEAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5993/5993_A_b1eiQ4BovAEAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5993/5993_A_EgytQoIRmCEAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5993/5993_A_EgytQoIRmCEAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5993/5993_A_EL3MTLdLMz8AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5993/5993_A_GDdvSZPa7M0AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5993/5993_A_GDdvSZPa7M0AAAAAAAAAAAAAAQAAAQ-0.jpg
#    creating: dog_data/5994/
#   inflating: dog_data/5994/5994_A_bJUVQLWonskAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5994/5994_A_bJUVQLWonskAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5994/5994_A_pNAcQKJ6yH4AAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5994/5994_A_qcBWSoqyLrEAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5994/5994_A_qcBWSoqyLrEAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5994/5994_A_sDy8TZweP6MAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5994/5994_A_sDy8TZweP6MAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5994/5994_A_v9o_T5ly55wAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5994/5994_A_YFdnQ5CoPhgAAAAAAAAAAAAAAQAAAQ.jpg
#    creating: dog_data/5995/
#   inflating: dog_data/5995/5995_A_7TWPT4_hkwwAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5995/5995_A_AcFbQoqDqRwAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5995/5995_A_ahGrQpcJLS8AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5995/5995_A_BFoHTKmmZckAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5995/5995_A_BFoHTKmmZckAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5995/5995_A_CWhQSqgeUq4AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5995/5995_A_CWhQSqgeUq4AAAAAAAAAAAAAAQAAAQ-0.jpg
#    creating: dog_data/5996/
#   inflating: dog_data/5996/5996_A_5j8qQIocWUwAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5996/5996_A_5j8qQIocWUwAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5996/5996_A_DhQlQKr7slQAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5996/5996_A_K9CLR4e8IykAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5996/5996_A_qzxeRo3Av5AAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5996/5996_A_-RuUS7F6LpsAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5996/5996_A_-RuUS7F6LpsAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5996/5996_A_t6AyT4K76akAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5996/5996_A_t6AyT4K76akAAAAAAAAAAAAAAQAAAQ-0.jpg
#    creating: dog_data/5997/
#   inflating: dog_data/5997/5997_A_1ruyQ7LcAuoAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5997/5997_A_1WHrSb70BwYAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5997/5997_A_GFtPRKYwYKQAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5997/5997_A_GFtPRKYwYKQAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5997/5997_A_LaERT6Vg6P0AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5997/5997_A_LaERT6Vg6P0AAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5997/5997_A_tjfGT6CxgFAAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5997/5997_A_uOCiT40f578AAAAAAAAAAAAAAQAAAQ.jpg
#    creating: dog_data/5998/
#   inflating: dog_data/5998/5998_8BujMxsVRvWOAhf1DW4HXgAAACMAARAD.jpg
#   inflating: dog_data/5998/5998_8BujMxsVRvWOAhf1DW4HXgAAACMAARAD-0.jpg
#   inflating: dog_data/5998/5998_ORZnfTwMTGmDKW-_9Zm_cAAAACMAARAD.jpg
#   inflating: dog_data/5998/5998_RJaJONp-R9-6Wg29qPh_MQAAACMAARAD.jpg
#   inflating: dog_data/5998/5998_s5_LPbJATXy82lMu1uSeJQAAACMAARAD.jpg
#   inflating: dog_data/5998/5998_s5_LPbJATXy82lMu1uSeJQAAACMAARAD-0.jpg
#   inflating: dog_data/5998/5998_xPWXoOz0RJ2uGy381aUq9wAAACMAARAD-0.jpg
#   inflating: dog_data/5998/5998_zusOFo_RSsqRAqtrfJ1fEgAAACMAARAD.jpg
#    creating: dog_data/5999/
#   inflating: dog_data/5999/5999_2A23mcKTRe6iwvdle-DnoQAAACMAARAD.jpg
#   inflating: dog_data/5999/5999_2A23mcKTRe6iwvdle-DnoQAAACMAARAD-0.jpg
#   inflating: dog_data/5999/5999_A_2nNMSZOEYsQAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5999/5999_A_59V-S7ievU8AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5999/5999_A_6nznR7Ek9MQAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5999/5999_A_H4FeQZ5TNVIAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5999/5999_A_H4FeQZ5TNVIAAAAAAAAAAAAAAQAAAQ-0.jpg
#   inflating: dog_data/5999/5999_A_hxoTSL4Np6AAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5999/5999_A_Lzq7RaU4LI8AAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5999/5999_A_plIEQ4aQaFEAAAAAAAAAAAAAAQAAAQ.jpg
#   inflating: dog_data/5999/5999_dTUY37UVRheaLCsCQ6X01AAAACMAARAD.jpg
#   inflating: dog_data/5999/5999_dTUY37UVRheaLCsCQ6X01AAAACMAARAD-0.jpg
#   inflating: dog_data/5999/5999_J9zK50Y5RvujoRzPnQkXBAAAACMAARAD.jpg

# %%
import os
import cv2
import time
import random
import numpy as np

import tensorflow as tf
from tensorflow.keras.applications.inception_v3 import preprocess_input

import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Setting random seeds to enable consistency while testing.
random.seed(5)
np.random.seed(5)
tf.random.set_seed(5)

ROOT = "/content/dog_data"
IMAGE_SIZE = (128, 128)

def read_image(index):
    path = os.path.join(ROOT, index[0], index[1])
    image = cv2.imread(path)
    image = cv2.resize(image, IMAGE_SIZE)  # Resize the image to 128x128
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    return image

# %%
def split_dataset(directory, split=0.9):
    folders = os.listdir(directory)
    num_train = int(len(folders) * split)

    random.shuffle(folders)

    train_list, test_list = {}, {}

    # Creating Train-list
    for folder in folders[:num_train]:
        num_files = len(os.listdir(os.path.join(directory, folder)))
        train_list[folder] = num_files

    # Creating Test-list
    for folder in folders[num_train:]:
        num_files = len(os.listdir(os.path.join(directory, folder)))
        test_list[folder] = num_files

    return train_list, test_list

train_list, test_list = split_dataset(ROOT, split=0.9)
print("Length of training list:", len(train_list))
print("Length of testing list :", len(test_list))

# train_list, test list contains the folder names along with the number of files in the folder.
print("\nTest List:", test_list)
# Out:
# Length of training list: 90
# Length of testing list : 10
#
# Test List: {'5946': 9, '5964': 8, '5996': 9, '5915': 8, '5941': 8, '5924': 11, '5901': 8, '5960': 6, '5967': 7, '5911': 7}

# %% [markdown]
# ### Creating Triplets
#
# We use the train and test list to create triplets of **(anchor, postive, negative)** face data, where positive is the same person and negative is a different person than anchor.

# %%
def create_triplets(directory, folder_list, max_files=10):
    triplets = []
    folders = list(folder_list.keys())

    for folder in folders:
        path = os.path.join(directory, folder)
        files = list(os.listdir(path))[:max_files]
        num_files = len(files)

        for i in range(num_files-1):
            for j in range(i+1, num_files):
                anchor = (folder, files[i])
                positive = (folder, files[j])

                neg_folder = folder
                while neg_folder == folder:
                    neg_folder = random.choice(folders)
                neg_files = list(os.listdir(os.path.join(directory, neg_folder)))
                neg_file = random.choice(neg_files)
                negative = (neg_folder, neg_file)

                triplets.append((anchor, positive, negative))

    random.shuffle(triplets)
    return triplets

# %%
train_triplet = create_triplets(ROOT, train_list)
test_triplet  = create_triplets(ROOT, test_list)

print("Number of training triplets:", len(train_triplet))
print("Number of testing triplets :", len(test_triplet))

print("\nExamples of triplets:")
for i in range(5):
    print(train_triplet[i])
# Out:
# Number of training triplets: 2427
# Number of testing triplets : 286
#
# Examples of triplets:
# (('5926', '5926_A_mwleR627z8oAAAAAAAAAAAAAAQAAAQ.jpg'), ('5926', '5926_A_eBxrT7u84_YAAAAAAAAAAAAAAQAAAQ.jpg'), ('5938', '5938_A_LUknQ5zwlPEAAAAAAAAAAAAAAQAAAQ.jpg'))
# (('5999', '5999_A_Lzq7RaU4LI8AAAAAAAAAAAAAAQAAAQ.jpg'), ('5999', '5999_2A23mcKTRe6iwvdle-DnoQAAACMAARAD.jpg'), ('5985', '5985_A_uzHRSJ5nN_cAAAAAAAAAAAAAAQAAAQ.jpg'))
# (('5983', '5983_A_lPjNSaZ7r9wAAAAAAAAAAAAAAQAAAQ.jpg'), ('5983', '5983_A_723fTJwuqewAAAAAAAAAAAAAAQAAAQ-0.jpg'), ('5989', '5989_A_fAd6Q6jPCKAAAAAAAAAAAAAAAQAAAQ.jpg'))
# (('5947', '5947_A_02oeQZQGpSIAAAAAAAAAAAAAAQAAAQ-0.jpg'), ('5947', '5947_A_Y7LpQZ9WcMQAAAAAAAAAAAAAAQAAAQ.jpg'), ('5993', '5993_A_EL3MTLdLMz8AAAAAAAAAAAAAAQAAAQ.jpg'))
# (('5962', '5962_A_8P78SYHj8vsAAAAAAAAAAAAAAQAAAQ.jpg'), ('5962', '5962_A_cUEKTLA6SR4AAAAAAAAAAAAAAQAAAQ.jpg'), ('5984', '5984_A_9z7ISKHMk40AAAAAAAAAAAAAAQAAAQ.jpg'))

# %% [markdown]
# ### Creating Batch-Generator
#
# Creating a **Batch-Generator** that converts the triplets passed into batches of face-data and **preproccesses** it before returning the data into seperate lists.
#
# **Parameters:**
# - Batch_size: Batch_size of the data to return
# - Preprocess: Whether to preprocess the data or not

# %%
def get_batch(triplet_list, batch_size=128, preprocess=True):
    batch_steps = len(triplet_list)//batch_size

    for i in range(batch_steps+1):
        anchor   = []
        positive = []
        negative = []

        j = i*batch_size
        while j<(i+1)*batch_size and j<len(triplet_list):
            a, p, n = triplet_list[j]
            anchor.append(read_image(a))
            positive.append(read_image(p))
            negative.append(read_image(n))
            j+=1

        anchor = np.array(anchor)
        positive = np.array(positive)
        negative = np.array(negative)

        if preprocess:
            anchor = preprocess_input(anchor)
            positive = preprocess_input(positive)
            negative = preprocess_input(negative)

        yield ([anchor, positive, negative])

# %% [markdown]
# ### Plotting the Data
#
# Plotting the data generated from **get_batch()** to see the results

# %%
num_plots = 6

f, axes = plt.subplots(num_plots, 3, figsize=(10, 10))

for x in get_batch(train_triplet, batch_size=num_plots, preprocess=False):
    a,p,n = x
    for i in range(num_plots):
        axes[i, 0].imshow(a[i])
        axes[i, 1].imshow(p[i])
        axes[i, 2].imshow(n[i])
        i+=1
    break

# %% [markdown]
# ## **Creating the Model**
#
# Unlike a conventional CNN, the **Siamese Network** does not classify the images into certain categories or labels, rather it only finds out the distance between any two given images. If the images have the same label, then the network should learn the parameters, i.e. the weights and the biases in such a way that it should produce a smaller distance between the two images, and if they belong to different labels, then the distance should be larger

# %%
from tensorflow.keras import backend, layers, metrics

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications import Xception
from tensorflow.keras.models import Model, Sequential

from tensorflow.keras.utils import plot_model
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %% [markdown]
# ### Encoder
#
# The **Encoder** is responsible for converting the passed images into their feature vectors. We're using a pretrained model, **Xception model** which is based on **Inception_V3 model.** By using transfer learning, we can significantly reduce the training time and size of the dataset.
#
# The Model is connected to **Fully Connected (Dense)** layers and the last layer normalises the data using **L2 Normalisation**. *(L2 Normalisation is a technique that modifies the dataset values in a way that in each row the sum of the squares will always be up to 1)*

# %%
def get_encoder(input_shape):
    """ Returns the image encoding model """

    pretrained_model = Xception(
        input_shape=input_shape,
        weights='imagenet',
        include_top=False,
        pooling='avg',
    )

    for i in range(len(pretrained_model.layers)-27):
        pretrained_model.layers[i].trainable = False

    encode_model = Sequential([
        pretrained_model,
        layers.Flatten(),
        layers.Dense(512, activation='relu'),
        layers.BatchNormalization(),
        layers.Dense(256, activation="relu"),
        layers.Lambda(lambda x: tf.math.l2_normalize(x, axis=1))
    ], name="Encode_Model")
    return encode_model

# %% [markdown]
# ### Siamese Network
#
# We're creating a **Siamese Network** that takes 3 input images, (anchor, postive, negative) and uses the encoder above to encode the images to their feature vectors. Those features are passed to a distance layer which computes the distance between **(anchor, positive)** and **(anchor, negative)** pairs.
#
# We'll be defining a custom layer to compute the distance.

# %%
class DistanceLayer(layers.Layer):
    # A layer to compute ‖f(A) - f(P)‖² and ‖f(A) - f(N)‖²
    def __init__(self, **kwargs):
        super().__init__(**kwargs)

    def call(self, anchor, positive, negative):
        ap_distance = tf.reduce_sum(tf.square(anchor - positive), -1)
        an_distance = tf.reduce_sum(tf.square(anchor - negative), -1)
        return (ap_distance, an_distance)


def get_siamese_network(input_shape = (128, 128, 3)):
    encoder = get_encoder(input_shape)

    # Input Layers for the images
    anchor_input   = layers.Input(input_shape, name="Anchor_Input")
    positive_input = layers.Input(input_shape, name="Positive_Input")
    negative_input = layers.Input(input_shape, name="Negative_Input")

    ## Generate the encodings (feature vectors) for the images
    encoded_a = encoder(anchor_input)
    encoded_p = encoder(positive_input)
    encoded_n = encoder(negative_input)

    # A layer to compute ‖f(A) - f(P)‖² and ‖f(A) - f(N)‖²
    distances = DistanceLayer()(
        encoded_a,
        encoded_p,
        encoded_n
    )
    # Creating the Model
    siamese_network = Model(
        inputs  = [anchor_input, positive_input, negative_input],
        outputs = distances,
        name = "Siamese_Network"
    )
    return siamese_network

siamese_network = get_siamese_network()
siamese_network.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 [==============================] - 0s 0us/step
# Model: "Siamese_Network"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  Anchor_Input (InputLayer)   [(None, 128, 128, 3)]        0         []
#
#  Positive_Input (InputLayer  [(None, 128, 128, 3)]        0         []
#  )
#
#  Negative_Input (InputLayer  [(None, 128, 128, 3)]        0         []
#  )
#
#  Encode_Model (Sequential)   (None, 256)                  2204394   ['Anchor_Input[0][0]',
#                                                           4          'Positive_Input[0][0]',
#                                                                      'Negative_Input[0][0]']
#
#  distance_layer (DistanceLa  ((None,),                    0         ['Encode_Model[0][0]',
#  yer)                         (None,))                               'Encode_Model[1][0]',
#                                                                      'Encode_Model[2][0]']
#
# ==================================================================================================
# Total params: 22043944 (84.09 MB)
# Trainable params: 9583800 (36.56 MB)
# Non-trainable params: 12460144 (47.53 MB)
# __________________________________________________________________________________________________

# %%
plot_model(siamese_network, show_shapes=True, show_layer_names=True)

# %% [markdown]
# ### Putting everything together
#
# We now need to implement a model with custom training loop and loss function so we can compute the **triplet loss** using the three embeddings produced by the Siamese network.
#
# We'll create a **Mean metric** instance to track the loss of the training process.
#
# **Triplet Loss Function:**
#
# <img src="https://miro.medium.com/max/1838/0*AX2TSZNk19_gDgTN.png" alt="Loss Formula" width="400"/>

# %%
class SiameseModel(Model):
    # Builds a Siamese model based on a base-model
    def __init__(self, siamese_network, margin=1.0):
        super(SiameseModel, self).__init__()

        self.margin = margin
        self.siamese_network = siamese_network
        self.loss_tracker = metrics.Mean(name="loss")

    def call(self, inputs):
        return self.siamese_network(inputs)

    def train_step(self, data):
        # GradientTape get the gradients when we compute loss, and uses them to update the weights
        with tf.GradientTape() as tape:
            loss = self._compute_loss(data)

        gradients = tape.gradient(loss, self.siamese_network.trainable_weights)
        self.optimizer.apply_gradients(zip(gradients, self.siamese_network.trainable_weights))

        self.loss_tracker.update_state(loss)
        return {"loss": self.loss_tracker.result()}

    def test_step(self, data):
        loss = self._compute_loss(data)

        self.loss_tracker.update_state(loss)
        return {"loss": self.loss_tracker.result()}

    def _compute_loss(self, data):
        # Get the two distances from the network, then compute the triplet loss
        ap_distance, an_distance = self.siamese_network(data)
        loss = tf.maximum(ap_distance - an_distance + self.margin, 0.0)
        return loss

    @property
    def metrics(self):
        # We need to list our metrics so the reset_states() can be called automatically.
        return [self.loss_tracker]

# %%
siamese_model = SiameseModel(siamese_network)

optimizer = Adam(learning_rate=1e-3, epsilon=1e-01)
siamese_model.compile(optimizer=optimizer)

# %% [markdown]
# ## **Training the Model**
#
# We'll now be training the siamese_model on batches of triplets. We'll print the training loss, along with additional metrics from testing every epoch. The model weights will also be saved whenever it outperforms the previous max_accuracy.
#
# ### Test Function
#
# **test_on_triplets()** function will be responsible for testing the model on test_triplets. It'll collect metrics **(accuracy, means, stds)** by predicting on the train data. We'll also be printing the Accuracy of the model after testing.

# %%
def test_on_triplets(batch_size = 256):
    pos_scores, neg_scores = [], []

    for data in get_batch(test_triplet, batch_size=batch_size):
        prediction = siamese_model.predict(data)
        pos_scores += list(prediction[0])
        neg_scores += list(prediction[1])

    accuracy = np.sum(np.array(pos_scores) < np.array(neg_scores)) / len(pos_scores)
    ap_mean = np.mean(pos_scores)
    an_mean = np.mean(neg_scores)
    ap_stds = np.std(pos_scores)
    an_stds = np.std(neg_scores)

    print(f"Accuracy on test = {accuracy:.5f}")
    return (accuracy, ap_mean, an_mean, ap_stds, an_stds)

# %%
import time
import numpy as np

save_all = False
batch_size = 128
max_epochs = 256
patience = 20  # Number of epochs to wait for improvement
best_accuracy = 0
epochs_without_improvement = 0

train_loss = []
test_metrics = []

for epoch in range(1, max_epochs + 1):
    t = time.time()

    # Training the model on train data
    epoch_loss = []
    for data in get_batch(train_triplet, batch_size=batch_size):
        loss = siamese_model.train_on_batch(data)
        epoch_loss.append(loss)
    epoch_loss = np.mean(epoch_loss)
    train_loss.append(epoch_loss)

    print(f"\nEPOCH: {epoch} \t (Epoch done in {int(time.time()-t)} sec)")
    print(f"Loss on train    = {epoch_loss:.5f}")

    # Testing the model on test data
    metric = test_on_triplets(batch_size=batch_size)
    test_metrics.append(metric)
    accuracy = metric[0]

    # Check if accuracy improved
    if accuracy > best_accuracy:
        best_accuracy = accuracy
        epochs_without_improvement = 0
        if save_all:
            siamese_model.save_weights("siamese_model")
    else:
        epochs_without_improvement += 1

    # Check for early stopping
    if epochs_without_improvement >= patience:
        print(f"\nEarly stopping at epoch {epoch}, no improvement for {patience} epochs.")
        break
# Out:
# EPOCH: 1 	 (Epoch done in 65 sec)
# Loss on train    = 0.31781
# 4/4 [==============================] - 6s 85ms/step
# 4/4 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 5s 5s/step
# Accuracy on test = 0.90210
#
# EPOCH: 2 	 (Epoch done in 24 sec)
# Loss on train    = 0.10250
# 4/4 [==============================] - 0s 118ms/step
# 4/4 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 36ms/step
# Accuracy on test = 0.89860
#
# EPOCH: 3 	 (Epoch done in 25 sec)
# Loss on train    = 0.04867
# 4/4 [==============================] - 0s 118ms/step
# 4/4 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 35ms/step
# Accuracy on test = 0.89161
#
# EPOCH: 4 	 (Epoch done in 25 sec)
# Loss on train    = 0.02368
# 4/4 [==============================] - 0s 120ms/step
# 4/4 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 41ms/step
# Accuracy on test = 0.87762
#
# EPOCH: 5 	 (Epoch done in 24 sec)
# Loss on train    = 0.01390
# 4/4 [==============================] - 0s 123ms/step
# 4/4 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 36ms/step
# Accuracy on test = 0.88462
#
# EPOCH: 6 	 (Epoch done in 23 sec)
# Loss on train    = 0.01004
# 4/4 [==============================] - 0s 126ms/step
# 4/4 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 34ms/step
# Accuracy on test = 0.89161
#
# EPOCH: 7 	 (Epoch done in 26 sec)
# Loss on train    = 0.01039
# 4/4 [==============================] - 0s 124ms/step
# 4/4 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 36ms/step
# Accuracy on test = 0.89510
#
# EPOCH: 8 	 (Epoch done in 24 sec)
# Loss on train    = 0.00725
# 4/4 [==============================] - 0s 120ms/step
# 4/4 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 35ms/step
# Accuracy on test = 0.84965
#
# EPOCH: 9 	 (Epoch done in 25 sec)
# Loss on train    = 0.00697
# 4/4 [==============================] - 0s 131ms/step
# 4/4 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 35ms/step
# Accuracy on test = 0.82867
#
# EPOCH: 10 	 (Epoch done in 25 sec)
# Loss on train    = 0.00606
# 4/4 [==============================] - 0s 128ms/step
# 4/4 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 35ms/step
# Accuracy on test = 0.87762
#
# EPOCH: 11 	 (Epoch done in 24 sec)
# Loss on train    = 0.00486
# 4/4 [==============================] - 0s 128ms/step
# 4/4 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 35ms/step
# Accuracy on test = 0.84965
#
# EPOCH: 12 	 (Epoch done in 25 sec)
# Loss on train    = 0.00324
# 4/4 [==============================] - 0s 128ms/step
# 4/4 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 39ms/step
# Accuracy on test = 0.86713
#
# EPOCH: 13 	 (Epoch done in 24 sec)
# Loss on train    = 0.00203
# 4/4 [==============================] - 0s 129ms/step
# 4/4 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 35ms/step
# Accuracy on test = 0.86364
#
# EPOCH: 14 	 (Epoch done in 25 sec)
# Loss on train    = 0.00042
# 4/4 [==============================] - 0s 131ms/step
# 4/4 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 36ms/step
# Accuracy on test = 0.85664
#
# EPOCH: 15 	 (Epoch done in 26 sec)
# Loss on train    = 0.00130
# 4/4 [==============================] - 0s 133ms/step
# 4/4 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 34ms/step
# Accuracy on test = 0.82517
#
# EPOCH: 16 	 (Epoch done in 25 sec)
# Loss on train    = 0.00076
# 4/4 [==============================] - 0s 127ms/step
# 4/4 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 48ms/step
# Accuracy on test = 0.86014
#
# EPOCH: 17 	 (Epoch done in 24 sec)
# Loss on train    = 0.00031
# 4/4 [==============================] - 0s 128ms/step
# 4/4 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 37ms/step
# Accuracy on test = 0.83217
#
# EPOCH: 18 	 (Epoch done in 26 sec)
# Loss on train    = 0.00039
# 4/4 [==============================] - 0s 128ms/step
# 4/4 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 40ms/step
# Accuracy on test = 0.83916
#
# EPOCH: 19 	 (Epoch done in 24 sec)
# Loss on train    = 0.00038
# 4/4 [==============================] - 0s 129ms/step
# 4/4 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 49ms/step
# Accuracy on test = 0.85315
#
# EPOCH: 20 	 (Epoch done in 24 sec)
# Loss on train    = 0.00011
# 4/4 [==============================] - 0s 128ms/step
# 4/4 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 34ms/step
# Accuracy on test = 0.85664
#
# EPOCH: 21 	 (Epoch done in 25 sec)
# Loss on train    = 0.00006
# 4/4 [==============================] - 0s 128ms/step
# 4/4 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 37ms/step
# Accuracy on test = 0.87063
#
# Early stopping at epoch 21, no improvement for 20 epochs.

# %%
siamese_model.summary()
# Out:
# Model: "siamese_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Siamese_Network (Functiona  ((None,),                 22043944
#  l)                           (None,))
#
# =================================================================
# Total params: 22043946 (84.09 MB)
# Trainable params: 9583800 (36.56 MB)
# Non-trainable params: 12460146 (47.53 MB)
# _________________________________________________________________

# %% [markdown]
# ## **Saving the Model Weights**

# %%
# Saving the model weights as directly saving wont work here after all epochs run
siamese_model.save_weights("siamese_model_folder/siamese_model-final")

# %% [markdown]
# ## Saving Model to drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

folder_name = 'SiameseNetwork'
folder_path = '/content/drive/My Drive/' + folder_name

if not os.path.exists(folder_path):
    os.makedirs(folder_path)
    print(f"Folder '{folder_name}' created successfully.")
else:
    print(f"Folder '{folder_name}' already exists.")
# Out:
# Folder 'SiameseNetwork' created successfully.

# %%
# !cp -r "/content/encoder_folder" "/content/drive/MyDrive/SiameseNetwork"

# %%
# !cp -r "/content/siamese_model_folder" "/content/drive/MyDrive/SiameseNetwork"

# %% [markdown]
# ## **Using the Model**
#
# Now that we've finished training our model, we need to **extract the encoder** so that we can use it to encode images and then get use the feature vectors to compute the distance between those images.
#
# We'll also be saving the encoder for latter use.

# %%
def extract_encoder(model):
    encoder = get_encoder((128, 128, 3))
    i=0
    for e_layer in model.layers[0].layers[3].layers:
        layer_weight = e_layer.get_weights()
        encoder.layers[i].set_weights(layer_weight)
        i+=1
    return encoder

encoder = extract_encoder(siamese_model)
encoder.save_weights("encoder_folder/" + "encoder")
encoder.summary()
# Out:
# Model: "Encode_Model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  xception (Functional)       (None, 2048)              20861480
#
#  flatten_4 (Flatten)         (None, 2048)              0
#
#  dense_8 (Dense)             (None, 512)               1049088
#
#  batch_normalization_24 (Ba  (None, 512)               2048
#  tchNormalization)
#
#  dense_9 (Dense)             (None, 256)               131328
#
#  lambda_4 (Lambda)           (None, 256)               0
#
# =================================================================
# Total params: 22043944 (84.09 MB)
# Trainable params: 9583800 (36.56 MB)
# Non-trainable params: 12460144 (47.53 MB)
# _________________________________________________________________

# %% [markdown]
# ### Classify Images
#
# To compute the distance between the encodings of the images, we'll be using distance formula. Distance over a certain threshold to be "different" and below the threshold as "same".

# %%
def classify_images(face_list1, face_list2, threshold=1.3):
    # Getting the encodings for the passed faces
    tensor1 = encoder.predict(face_list1)
    tensor2 = encoder.predict(face_list2)

    distance = np.sum(np.square(tensor1-tensor2), axis=-1)
    prediction = np.where(distance<=threshold, 0, 1)
    return prediction

# %%
def ModelMetrics(pos_list, neg_list):
    true = np.array([0]*len(pos_list)+[1]*len(neg_list))
    pred = np.append(pos_list, neg_list)

    # Compute and print the accuracy
    print(f"\nAccuracy of model: {accuracy_score(true, pred)}\n")

    # Compute and plot the Confusion matrix
    cf_matrix = confusion_matrix(true, pred)

    categories  = ['Similar','Different']
    names = ['True Similar','False Similar', 'False Different','True Different']
    percentages = ['{0:.2%}'.format(value) for value in cf_matrix.flatten() / np.sum(cf_matrix)]

    labels = [f'{v1}\n{v2}' for v1, v2 in zip(names, percentages)]
    labels = np.asarray(labels).reshape(2,2)

    sns.heatmap(cf_matrix, annot = labels, cmap = 'Blues',fmt = '',
                xticklabels = categories, yticklabels = categories)

    plt.xlabel("Predicted", fontdict = {'size':14}, labelpad = 10)
    plt.ylabel("Actual"   , fontdict = {'size':14}, labelpad = 10)
    plt.title ("Confusion Matrix", fontdict = {'size':18}, pad = 20)


pos_list = np.array([])
neg_list = np.array([])

for data in get_batch(test_triplet, batch_size=256):
    a, p, n = data
    pos_list = np.append(pos_list, classify_images(a, p))
    neg_list = np.append(neg_list, classify_images(a, n))
    break

ModelMetrics(pos_list, neg_list)
# Out:
# 8/8 [==============================] - 1s 48ms/step
# 8/8 [==============================] - 0s 35ms/step
# 8/8 [==============================] - 0s 35ms/step
# 8/8 [==============================] - 0s 35ms/step
#
# Accuracy of model: 0.810546875
